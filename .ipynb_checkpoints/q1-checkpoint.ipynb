# %% [markdown]
# # Q1

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams["figure.figsize"] = (10,8)

# I'm assuming I can't use pandas here becuase that's what I would usually use
# Only using matplotlib for visualisation

# %%
# Preprocessing

def norm(x):
    '''Normalisation function using standard score.'''
    return (x - np.mean(x)) / np.std(x)

# Load in data
avocado_data = {}
for i in np.genfromtxt('avocado.csv', delimiter=',', dtype='str').T:
    avocado_data[i[0]] = i[1:]

# Cast numeric data to floats and normalise
numerical_data = ['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'year']
for i in numerical_data:
    avocado_data[i] = avocado_data[i].astype(float)
    
# Convert date to np.datetime64
avocado_data['Date'] = avocado_data['Date'].astype(np.datetime64)

# print(avocado_data)

# %%
len(np.argwhere(avocado_data['Total Volume'])), len(avocado_data['Total Volume'])
max(avocado_data['Total Volume'])
# Out:
# 62505646.52

# %%
# Introductory plotting
# There are a huge number of values really close to 0 then a cluster of outlying
# more extreme values
x_label = 'Total Volume'
y_label = 'AveragePrice'
plt.scatter(avocado_data[x_label], avocado_data[y_label])
plt.ylabel(y_label)
_ = plt.xlabel(x_label)

# %%
# There are a large number of outliers affecting the data
plt.boxplot(avocado_data['Total Volume'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fdd81cc3f60>,
#   <matplotlib.lines.Line2D at 0x7fdd81ca43c8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fdd81ca47f0>,
#   <matplotlib.lines.Line2D at 0x7fdd81ca4c18>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fdd81cc39e8>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fdd81ca4cf8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fdd81cb04a8>],
#  'means': []}

# %%
class LinearRegression:
    '''Very simple linear regression model.'''
    
    def __init__(self, y):
        '''Initialise model with y values.
        
        Args:
            y: list-like, y values to fit model to
        '''
        self.y = y
        
    def fit(self, x):
        '''Fit model to given input.
        
        Args:
            x: list-like, x values to fit model to
        '''
        self.m = self.grad(x)
        self.b = self.inter(x)
    
    def grad(self, x):
        '''Calculate gradient of regression.
        
        Args:
            x: list-like, x values to fit model to
        '''
        return (len(x) * np.sum(x*self.y) - np.sum(x) * np.sum(self.y)) / (len(x)*np.sum(x*x) - np.sum(x) ** 2)
        
    def inter(self, x):
        '''Calculate y-intercept of regression.
        
        Args:
            x: list-like, x values to fit model to
        '''
        return (np.sum(self.y) - m * np.sum(x)) / len(x)
    
    def predict(self, x):
        '''Predict new x values.
        
        Args:
            x: list-like, x values to predict y values for
        '''
        return self.m * x + self.b

# %%
y = avocado_data['AveragePrice']
model = LinearRegression(y)

for idx, i in enumerate(numerical_data):
    x = avocado_data[i]
    model.fit(x)
    print(i, model.m, model.b)
    
    plt.subplot(len(numerical_data), 1, idx+1)
    plt.scatter(avocado_data[x_label], avocado_data[y_label])
    plt.ylabel('Average Price')
    plt.xlabel(i)
# Out:
# AveragePrice 1.0 1.4059785423501332
# Total Volume -2.2474546975574275e-08 1.4861883872025206
# 4046 -6.63123443083059e-08 1.433607122560545
# 4225 -5.782973174272077e-08 1.433809489408672
# 4770 -6.723986145186242e-07 1.40813204241231
# Total Bags -7.230388500917484e-08 1.428574765823536
# Small Bags -9.429323688874337e-08 1.4231581365283468
# Large Bags -2.8544509303542826e-07 1.411102123993374
# XLarge Bags -2.676294104826901e-06 1.4062713247863994
# year 0.0399262735746884 1.4061685188872755
